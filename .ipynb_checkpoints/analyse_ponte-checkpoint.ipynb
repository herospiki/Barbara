# %%
import pandas as pd

# %%
ponte_df = pd.read_csv('ponte.csv', sep=';')
ponte_df
# Out:
#         Date Joséphine Albertine Augustine Cunégonde Pioupioute Valérie  \
# 0    1-janv.         x       NaN       NaN         x        NaN     NaN
# 1    2-janv.         x       NaN       NaN         x        NaN     NaN
# 2    3-janv.         x       NaN       NaN         x        NaN     NaN
# 3    4-janv.         x       NaN       NaN       NaN        NaN     NaN
# 4    5-janv.         x       NaN       NaN         x        NaN     NaN
# ..       ...       ...       ...       ...       ...        ...     ...
# 361  27-déc.       NaN         x       NaN         x        NaN     NaN
# 362  28-déc.       NaN       NaN       NaN       NaN        NaN     NaN
# 363  29-déc.       NaN         x       NaN         x        NaN     NaN
# 364  30-déc.       NaN       NaN       NaN       NaN        NaN     NaN
# 365  31-déc.       NaN        x?       NaN         x        NaN     NaN
#
#     Rémiel Saquiel T°C (12-15h) T°C poulailler Pluie (0 = non renseigné)  \
# ...

# %%
ponte_df.describe()
# Out:
#            Date Joséphine Albertine Augustine Cunégonde Pioupioute Valérie  \
# count       366       223       108        11       194         71     117
# unique      366         3         5         5         3          6       4
# top     1-janv.         x         x         x         x          x       x
# freq          1       220       100         7       191         53     114
#
#        Rémiel Saquiel T°C (12-15h) T°C poulailler Pluie (0 = non renseigné)  \
# count      74      42          363            189                       354
# unique      6       6           39             30                        32
# top         x       x           15             20                         0
# freq       61      20           20             14                       234
#
#        Météo          commentaires
# count    362                    93
# unique    97                    79
# top     beau  avhydratC+Gascodrène
# freq     128                     8

# %%
ponte_df.melt(id_vars=['Date', 'T°C (12-15h)','T°C poulailler','Pluie (0 = non renseigné)','Météo','commentaires'], value_vars=['Joséphine','Albertine','Augustine','Cunégonde','Pioupioute','Valérie','Rémiel','Saquiel'], 
              var_name='Nom de la poule', value_name='Ponte')
# Out:
#          Date T°C (12-15h) T°C poulailler Pluie (0 = non renseigné)  \
# 0     1-janv.          NaN            NaN                       NaN
# 1     2-janv.          NaN            NaN                       NaN
# 2     3-janv.          NaN            NaN                       NaN
# 3     4-janv.           15            NaN                         0
# 4     5-janv.           14            NaN                         0
# ...       ...          ...            ...                       ...
# 2923  27-déc.           17              5                         0
# 2924  28-déc.           10              4                         0
# 2925  29-déc.            9              7                         0
# 2926  30-déc.           17              7                         0
# 2927  31-déc.            7              6                         2
#
#                 Météo           commentaires Nom de la poule Ponte
# 0                 NaN                    NaN       Joséphine     x
# ...
